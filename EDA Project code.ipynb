# %% [markdown]
# # <center>Google-Play-Store Analysis

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import and Preview of the First 10 Records from the Google Play Store Dataset

# %%
inp0=pd.read_csv("googleplaystore.csv")
inp0.head(10)
# Out:
#                                      googleplaystore      Unnamed: 1  \
# 0                                         Unnamed: 1             NaN
# 1                                                App        Category
# 2     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 3                                Coloring book moana  ART_AND_DESIGN
# 4  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 5                              Sketch - Draw & Paint  ART_AND_DESIGN
# 6              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 7                         Paper flowers instructions  ART_AND_DESIGN
# 8            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 9                                   Infinite Painter  ART_AND_DESIGN
#
#   Unnamed: 2 Unnamed: 3  Unnamed: 4   Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN  Unnamed:4  Unnamed: 5          NaN        NaN        NaN
# 1     Rating    Reviews        Size     Installs       Type      Price
# 2        4.1        159         19M      10,000+       Free          0
# 3        3.9        967         14M     500,000+       Free          0
# 4        4.7      87510        8.7M   5,000,000+       Free          0
# 5        4.5     215644         25M  50,000,000+       Free          0
# 6        4.3        967        2.8M     100,000+       Free          0
# 7        4.4        167        5.6M      50,000+       Free          0
# 8        3.8        178         19M      50,000+       Free          0
# 9        4.1      36815         29M   1,000,000+       Free          0
#
#       Unnamed: 8                 Unnamed: 9       Unnamed: 10  \
# 0     Unnamed: 9                Unnamed: 10       Unnamed: 11
# 1  ContentRating                     Genres       LastUpdated
# 2       Everyone               Art & Design   January 7, 2018
# 3       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4       Everyone               Art & Design    August 1, 2018
# 5           Teen               Art & Design      June 8, 2018
# 6       Everyone    Art & Design;Creativity     June 20, 2018
# 7       Everyone               Art & Design    March 26, 2017
# 8       Everyone               Art & Design    April 26, 2018
# 9       Everyone               Art & Design     June 14, 2018
#
#           Unnamed: 11   Unnamed: 12
# 0         Unnamed: 12           NaN
# 1          CurrentVer    AndroidVer
# 2               1.0.0  4.0.3 and up
# 3               2.0.0  4.0.3 and up
# 4               1.2.4  4.0.3 and up
# 5  Varies with device    4.2 and up
# 6                 1.1    4.4 and up
# 7                   1    2.3 and up
# 8                 1.1  4.0.3 and up
# 9            6.1.61.1    4.2 and up

# %% [markdown]
# ### Dimensions of the Google Play Store Dataset

# %%
inp0.shape
# Out:
# (10843, 13)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Loading Google Play Store Data (Skipping First Two Rows)

# %%
inp0=pd.read_csv("googleplaystore.csv",skiprows=2)
inp0.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price ContentRating  \
# 0     159   19M      10,000+  Free     0      Everyone
# 1     967   14M     500,000+  Free     0      Everyone
# 2   87510  8.7M   5,000,000+  Free     0      Everyone
# 3  215644   25M  50,000,000+  Free     0          Teen
# 4     967  2.8M     100,000+  Free     0      Everyone
# 5     167  5.6M      50,000+  Free     0      Everyone
# 6     178   19M      50,000+  Free     0      Everyone
# 7   36815   29M   1,000,000+  Free     0      Everyone
# 8   13791   33M   1,000,000+  Free     0      Everyone
# 9     121  3.1M      10,000+  Free     0      Everyone
#
#                       Genres         LastUpdated          CurrentVer  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                   1
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#      AndroidVer
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %% [markdown]
# ### To get missing in each columns

# %%
inp0.isnull().sum()
# Out:
# App                 0
# Category            0
# Rating           1474
# Reviews             0
# Size                0
# Installs            0
# Type                1
# Price               0
# ContentRating       1
# Genres              0
# LastUpdated         0
# CurrentVer          8
# AndroidVer          3
# dtype: int64

# %% [markdown]
# ### To get more information about the dataset

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            10841 non-null  object
#  1   Category       10841 non-null  object
#  2   Rating         9367 non-null   float64
#  3   Reviews        10841 non-null  object
#  4   Size           10841 non-null  object
#  5   Installs       10841 non-null  object
#  6   Type           10840 non-null  object
#  7   Price          10841 non-null  object
#  8   ContentRating  10840 non-null  object
#  9   Genres         10841 non-null  object
#  10  LastUpdated    10841 non-null  object
#  11  CurrentVer     10833 non-null  object
#  12  AndroidVer     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Summary Statistics of Google Play Store Data

# %%
inp0.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Calculating the Variance for Each Numeric Column in the Dataset

# %%
inp0.var()
# Out:
# Rating    0.288832
# dtype: float64

# %% [markdown]
# ### Computing the Fractional Percentage of a Specific Data Point

# %%
(100*1474/10841)
# Out:
# 13.596531685268886

# %% [markdown]
# ## <center> Dividing Columns for more data

# %% [markdown]
# ## Dividing LastUpdated Column into LastUpdated_Month_date and LastUpdated_Year

# %% [markdown]
# ### Extracting Month and Date from the "LastUpdated" Column

# %%
inp0["LastUpdated_Month_date"]=inp0.LastUpdated.apply(lambda x: x.split(",")[0])
inp0.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price ContentRating  \
# 0     159   19M      10,000+  Free     0      Everyone
# 1     967   14M     500,000+  Free     0      Everyone
# 2   87510  8.7M   5,000,000+  Free     0      Everyone
# 3  215644   25M  50,000,000+  Free     0          Teen
# 4     967  2.8M     100,000+  Free     0      Everyone
#
#                       Genres       LastUpdated          CurrentVer  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#      AndroidVer LastUpdated_Month_date
# 0  4.0.3 and up              January 7
# 1  4.0.3 and up             January 15
# 2  4.0.3 and up               August 1
# 3    4.2 and up                 June 8
# 4    4.4 and up                June 20

# %% [markdown]
# ### Handling Missing Data in 'LastUpdated' by Replacing NaN with Empty String

# %%
inp0["LastUpdated"] = inp0["LastUpdated"].fillna('')

# %% [markdown]
# ### Extracting the Year from the 'LastUpdated' Column

# %%
inp0['LastUpdated_Year'] = inp0['LastUpdated'].str.split(',').str[1].str.strip()
inp0.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price ContentRating  \
# 0     159   19M      10,000+  Free     0      Everyone
# 1     967   14M     500,000+  Free     0      Everyone
# 2   87510  8.7M   5,000,000+  Free     0      Everyone
# 3  215644   25M  50,000,000+  Free     0          Teen
# 4     967  2.8M     100,000+  Free     0      Everyone
#
#                       Genres       LastUpdated          CurrentVer  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#      AndroidVer LastUpdated_Month_date LastUpdated_Year
# 0  4.0.3 and up              January 7             2018
# 1  4.0.3 and up             January 15             2018
# 2  4.0.3 and up               August 1             2018
# 3    4.2 and up                 June 8             2018
# 4    4.4 and up                June 20             2018

# %% [markdown]
# ### Dropping the 'LastUpdated' Column from the Dataset

# %%
inp0.drop("LastUpdated",axis=1,inplace=True)
inp0.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price ContentRating  \
# 0     159   19M      10,000+  Free     0      Everyone
# 1     967   14M     500,000+  Free     0      Everyone
# 2   87510  8.7M   5,000,000+  Free     0      Everyone
# 3  215644   25M  50,000,000+  Free     0          Teen
# 4     967  2.8M     100,000+  Free     0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
#
#   LastUpdated_Month_date LastUpdated_Year
# 0              January 7             2018
# 1             January 15             2018
# 2               August 1             2018
# 3                 June 8             2018
# 4                June 20             2018

# %% [markdown]
# ## <center>Handling missing values for RATING COLUMNS
# ######    Rating is the target variable
# ######   Drop the records

# %% [markdown]
# ### Creating Dataset Without Missing Ratings

# %%
inp1=inp0[~inp0.Rating.isnull()]
inp1.shape
# Out:
# (9367, 14)

# %% [markdown]
# ### Checking for Null Values in the 'Rating' Column

# %%
#Because we drop the null columns 
inp1.Rating.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Identifying Null Values in Each Column of the DataFrame

# %%
inp1.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# ContentRating             1
# Genres                    0
# CurrentVer                4
# AndroidVer                3
# LastUpdated_Month_date    0
# LastUpdated_Year          1
# dtype: int64

# %% [markdown]
# ## <center>Explore/understand the Null Values for the column Android version

# %% [markdown]
# ### Extracting Rows with Missing 'AndroidVer' Values

# %%
inp1[inp1['AndroidVer'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price ContentRating  \
# 4453      230     11M   1,000+  Paid     $1.49      Everyone
# 4490      189    2.1M  10,000+  Free         0      Everyone
# 10472    3.0M  1,000+     Free     0  Everyone           NaN
#
#                   Genres  CurrentVer AndroidVer LastUpdated_Month_date  \
# 4453     Personalization         4.4        NaN                July 20
# 4490     Personalization         1.1        NaN               March 27
# 10472  February 11, 2018  4.0 and up        NaN                 1.0.19
#
#       LastUpdated_Year
# 4453              2018
# 4490              2018
# 10472              NaN

# %% [markdown]
# ## <center> Dropping

# %% [markdown]
# ### Retrieving Data for the App at Index 10472

# %%
#to get that column
inp1.loc[10472,:]
# Out:
# App                       Life Made WI-Fi Touchscreen Photo Frame
# Category                                                      1.9
# Rating                                                       19.0
# Reviews                                                      3.0M
# Size                                                       1,000+
# Installs                                                     Free
# Type                                                            0
# Price                                                    Everyone
# ContentRating                                                 NaN
# Genres                                          February 11, 2018
# CurrentVer                                             4.0 and up
# AndroidVer                                                    NaN
# LastUpdated_Month_date                                     1.0.19
# LastUpdated_Year                                              NaN
# Name: 10472, dtype: object

# %% [markdown]
# ### Extracting Entries with Missing 'AndroidVer' and Category 1.9

# %%
#To get row where the androidver is null and category==1.9
inp1[(inp1['AndroidVer'].isnull() & (inp1.Category=="1.9"))]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price ContentRating             Genres  \
# 10472  1,000+     Free    0  Everyone           NaN  February 11, 2018
#
#        CurrentVer AndroidVer LastUpdated_Month_date LastUpdated_Year
# 10472  4.0 and up        NaN                 1.0.19              NaN

# %% [markdown]
# ### Dropping Rows with Missing 'AndroidVer' for Category 1.9

# %%
# we drop that column 
inp1=inp1[~(inp1['AndroidVer'].isnull() & (inp1.Category=="1.9"))]

# %% [markdown]
# ### Extracting Rows Where 'AndroidVer' is Null

# %%
inp1[inp1['AndroidVer'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price ContentRating           Genres CurrentVer AndroidVer  \
# 4453  Paid  $1.49      Everyone  Personalization        4.4        NaN
# 4490  Free      0      Everyone  Personalization        1.1        NaN
#
#      LastUpdated_Month_date LastUpdated_Year
# 4453                July 20             2018
# 4490               March 27             2018

# %%
# to get the count of the each type in Androidver column
inp1['AndroidVer'].value_counts()
# Out:
# 4.1 and up            2059
# Varies with device    1319
# 4.0.3 and up          1240
# 4.0 and up            1131
# 4.4 and up             875
# 2.3 and up             582
# 5.0 and up             535
# 4.2 and up             338
# 2.3.3 and up           240
# 3.0 and up             211
# 2.2 and up             208
# 4.3 and up             207
# 2.1 and up             113
# 1.6 and up              87
# 6.0 and up              48
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              18
# 1.5 and up              16
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              6
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# Name: AndroidVer, dtype: int64

# %%
# to get the Mode of the column
inp1['AndroidVer'].mode()[0]
# Out:
# '4.1 and up'

# %% [markdown]
# ### Filling the NANs with this values

# %%
# Filling the missing values with the mode values
inp1['AndroidVer']=inp1['AndroidVer'].fillna(inp1['AndroidVer'].mode()[0])

# %% [markdown]
# ### Getting the Frequency of Unique Values in 'AndroidVer'

# %%
# After run about code mode type is increased
inp1['AndroidVer'].value_counts()
# Out:
# 4.1 and up            2061
# Varies with device    1319
# 4.0.3 and up          1240
# 4.0 and up            1131
# 4.4 and up             875
# 2.3 and up             582
# 5.0 and up             535
# 4.2 and up             338
# 2.3.3 and up           240
# 3.0 and up             211
# 2.2 and up             208
# 4.3 and up             207
# 2.1 and up             113
# 1.6 and up              87
# 6.0 and up              48
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              18
# 1.5 and up              16
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              6
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# Name: AndroidVer, dtype: int64

# %% [markdown]
# ### Verifying That All Missing 'AndroidVer' Entries Have Been Handled

# %%
#We get 0 beacuse we handle the missing values in AndroidVer column
inp1['AndroidVer'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Identifying Null Values in Each Column of the DataFrame

# %%
inp1.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# ContentRating             0
# Genres                    0
# CurrentVer                4
# AndroidVer                0
# LastUpdated_Month_date    0
# LastUpdated_Year          0
# dtype: int64

# %% [markdown]
# ## <center>Handling Missing values in 'CURRENT VERSION'

# %% [markdown]
# ### Getting the Frequency Distribution of Versions in 'CurrentVer'

# %%
inp1['CurrentVer'].value_counts()
# Out:
# Varies with device    1415
# 1                      476
# 1.1                    206
# 1.2                    133
# 2                      129
#                       ...
# 1.3.A.2.9                1
# 9.9.1.1910               1
# 7.1.34.28                1
# 5.9.7                    1
# 0.3.4                    1
# Name: CurrentVer, Length: 2594, dtype: int64

# %% [markdown]
# ### Replace the missing values with "Varies with devices"

# %% [markdown]
# ### Getting Rows with Non-Missing 'CurrentVer' Values

# %%
#to get the Non-null values rows in currentversion
inp1[~inp1['CurrentVer'].isnull()]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10834     4.0       7                2.6M         500+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       ContentRating                     Genres          CurrentVer  \
# 0          Everyone               Art & Design               1.0.0
# 1          Everyone  Art & Design;Pretend Play               2.0.0
# 2          Everyone               Art & Design               1.2.4
# 3              Teen               Art & Design  Varies with device
# 4          Everyone    Art & Design;Creativity                 1.1
# ...             ...                        ...                 ...
# 10834      Everyone                  Education               1.0.0
# 10836      Everyone                  Education                1.48
# 10837      Everyone                  Education                   1
# 10839    Mature 17+          Books & Reference  Varies with device
# 10840      Everyone                  Lifestyle  Varies with device
#
#                AndroidVer LastUpdated_Month_date LastUpdated_Year
# 0            4.0.3 and up              January 7             2018
# 1            4.0.3 and up             January 15             2018
# 2            4.0.3 and up               August 1             2018
# 3              4.2 and up                 June 8             2018
# 4              4.4 and up                June 20             2018
# ...                   ...                    ...              ...
# 10834          4.1 and up                June 18             2017
# 10836          4.1 and up                July 25             2017
# 10837          4.1 and up                 July 6             2018
# 10839  Varies with device             January 19             2015
# 10840  Varies with device                July 25             2018
#
# [9362 rows x 14 columns]

# %% [markdown]
# ### Finding the Mode (Most Common Value) in 'CurrentVer'

# %%
# to get the mode in current version
inp1['CurrentVer'].mode()[0]
# Out:
# 'Varies with device'

# %% [markdown]
# ### Imputing Null 'CurrentVer' Entries with the Most Frequent Value

# %%
#We set the mode in null Columns
inp1['CurrentVer']=inp1['CurrentVer'].fillna(inp1['CurrentVer'].mode()[0])

# %% [markdown]
# ### Getting the Frequency Distribution of Versions in 'CurrentVer'

# %%
inp1['CurrentVer'].value_counts()
# Out:
# Varies with device    1419
# 1                      476
# 1.1                    206
# 1.2                    133
# 2                      129
#                       ...
# 1.3.A.2.9                1
# 9.9.1.1910               1
# 7.1.34.28                1
# 5.9.7                    1
# 0.3.4                    1
# Name: CurrentVer, Length: 2594, dtype: int64

# %% [markdown]
# ### Counting Missing Values in 'CurrentVer' After Imputation

# %%
inp1['CurrentVer'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Identifying Null Values in Each Column of the DataFrame

# %%
inp1.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# ContentRating             0
# Genres                    0
# CurrentVer                0
# AndroidVer                0
# LastUpdated_Month_date    0
# LastUpdated_Year          0
# dtype: int64

# %% [markdown]
# ## <center>Change the variables to the correct Data types

# %% [markdown]
# ### Checking Column Data Types in inp1

# %%
inp1.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                    object
# Size                       object
# Installs                   object
# Type                       object
# Price                      object
# ContentRating              object
# Genres                     object
# CurrentVer                 object
# AndroidVer                 object
# LastUpdated_Month_date     object
# LastUpdated_Year           object
# dtype: object

# %%
inp1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price ContentRating  \
# 0     159   19M      10,000+  Free     0      Everyone
# 1     967   14M     500,000+  Free     0      Everyone
# 2   87510  8.7M   5,000,000+  Free     0      Everyone
# 3  215644   25M  50,000,000+  Free     0          Teen
# 4     967  2.8M     100,000+  Free     0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
#
#   LastUpdated_Month_date LastUpdated_Year
# 0              January 7             2018
# 1             January 15             2018
# 2               August 1             2018
# 3                 June 8             2018
# 4                June 20             2018

# %% [markdown]
# ### Handling price Columns data type

# %% [markdown]
# ### Counting Occurrences of Each Price in the 'Price' Column

# %%
inp1.Price.value_counts()
# Out:
# 0          8719
# $2.99       114
# $0.99       107
# $4.99        70
# $1.99        59
#            ...
# $1.29         1
# $299.99       1
# $379.99       1
# $37.99        1
# $1.20         1
# Name: Price, Length: 73, dtype: int64

# %% [markdown]
# ### Converting 'Price' Column to Numeric Type After Removing  "$" Symbol

# %%
inp1.Price=inp1.Price.apply(lambda x:0 if x=="0" else float(x[1:]))

# %% [markdown]
# ### Counting Occurrences of Each Price in the 'Price' Column

# %%
inp1.Price.value_counts()
# Out:
# 0.00      8719
# 2.99       114
# 0.99       107
# 4.99        70
# 1.99        59
#           ...
# 1.29         1
# 299.99       1
# 379.99       1
# 37.99        1
# 1.20         1
# Name: Price, Length: 73, dtype: int64

# %% [markdown]
# ### Displaying the Data Type of 'Price' Column

# %%
inp1.Price.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Handle the reviews colums DataTypes

# %% [markdown]
# ### Counting Occurrences of Each Price in the 'Price' Column

# %%
inp1.Reviews.value_counts()
# Out:
# 2         83
# 3         78
# 4         74
# 5         74
# 1         67
#           ..
# 49657      1
# 41420      1
# 7146       1
# 44706      1
# 398307     1
# Name: Reviews, Length: 5992, dtype: int64

# %% [markdown]
# ### Converting 'Reviews' Column to Integer Type

# %%
inp1.Reviews=inp1.Reviews.astype("int32")

# %% [markdown]
# ### Inspecting the Data Type of 'Reviews' After Conversion

# %%
inp1.Reviews.dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### Descriptive Statistics of 'Reviews'

# %%
inp1.Reviews.describe()
# Out:
# count    9.366000e+03
# mean     5.140498e+05
# std      3.144042e+06
# min      1.000000e+00
# 25%      1.862500e+02
# 50%      5.930500e+03
# 75%      8.153275e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# ### Checking Column Data Types in inp1

# %%
inp1.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                     int32
# Size                       object
# Installs                   object
# Type                       object
# Price                     float64
# ContentRating              object
# Genres                     object
# CurrentVer                 object
# AndroidVer                 object
# LastUpdated_Month_date     object
# LastUpdated_Year           object
# dtype: object

# %% [markdown]
# ### Showing the First 5 Rows of 'Installs'

# %%
inp1.Installs.head()
# Out:
# 0        10,000+
# 1       500,000+
# 2     5,000,000+
# 3    50,000,000+
# 4       100,000+
# Name: Installs, dtype: object

# %% [markdown]
# ## <center> Clean up or handle the INSTALLS column

# %% [markdown]
# ### Function to Clean 'Installs' Values by Removing Commas and Plus Signs

# %%
def clean_installs(val):
    return int(val.replace(",","").replace("+",""))

# %% [markdown]
# ### Cleaning and Converting 'Installs' Value to Integer

# %%
clean_installs("3,000+")
# Out:
# 3000

# %% [markdown]
# ### Transforming 'Installs' String with Comma and Plus to Integer

# %%
type(clean_installs("300,00+"))
# Out:
# int

# %%
inp1.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type  Price ContentRating  \
# 0      159   19M      10,000+  Free    0.0      Everyone
# 1      967   14M     500,000+  Free    0.0      Everyone
# 2    87510  8.7M   5,000,000+  Free    0.0      Everyone
# 3   215644   25M  50,000,000+  Free    0.0          Teen
# 4      967  2.8M     100,000+  Free    0.0      Everyone
# 5      167  5.6M      50,000+  Free    0.0      Everyone
# 6      178   19M      50,000+  Free    0.0      Everyone
# 7    36815   29M   1,000,000+  Free    0.0      Everyone
# 8    13791   33M   1,000,000+  Free    0.0      Everyone
# 9      121  3.1M      10,000+  Free    0.0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
# 5               Art & Design                   1    2.3 and up
# 6               Art & Design                 1.1  4.0.3 and up
# 7               Art & Design            6.1.61.1    4.2 and up
# 8               Art & Design               2.9.2    3.0 and up
# 9    Art & Design;Creativity                 2.8  4.0.3 and up
#
#   LastUpdated_Month_date LastUpdated_Year
# 0              January 7             2018
# 1             January 15             2018
# 2               August 1             2018
# 3                 June 8             2018
# 4                June 20             2018
# 5               March 26             2017
# 6               April 26             2018
# 7                June 14             2018
# 8           September 20             2017
# 9                 July 3             2018

# %% [markdown]
# ### Data Cleaning for 'Installs' Column with clean_installs Functio

# %%
inp1.Installs=inp1.Installs.apply(clean_installs)

# %% [markdown]
# ### Summary Statistics for the 'Installs' Data

# %%
inp1.Installs.describe
# Out:
# <bound method NDFrame.describe of 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9366, dtype: int64>

# %% [markdown]
# ## <center> Cleaning Size Columns

# %% [markdown]
# ### Cleaning 'Size' Column by Converting 'M' and 'K' to Numeric Values

# %%
def clean_size(val):
    if 'M' in val:
        return float(float(val.replace("M", "")) * 1000)
    elif 'K' in val:
        return float(val.replace("K", ""))
    else:
        return float()

# %% [markdown]
# ### Converting 'Size' from Megabytes to Kilobytes

# %%
clean_size("19M")
# Out:
# 19000.0

# %% [markdown]
# ### Applying clean_size Function to the 'Size' Column

# %%
inp1.Size=inp1.Size.apply(clean_size)

# %%
inp1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price ContentRating  \
# 0      159  19000.0     10000  Free    0.0      Everyone
# 1      967  14000.0    500000  Free    0.0      Everyone
# 2    87510   8700.0   5000000  Free    0.0      Everyone
# 3   215644  25000.0  50000000  Free    0.0          Teen
# 4      967   2800.0    100000  Free    0.0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
#
#   LastUpdated_Month_date LastUpdated_Year
# 0              January 7             2018
# 1             January 15             2018
# 2               August 1             2018
# 3                 June 8             2018
# 4                June 20             2018

# %% [markdown]
# ### Removing Rows with 'Unrated' and 'Adults Only 18+' Content Ratings

# %%
inp1 = inp1[~inp1['ContentRating'].isin(['Unrated', 'Adults only 18+'])]

# %% [markdown]
# ## <center>Identifying and handling outliers/extreme values

# %% [markdown]
# ### Importing libraries for visulization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Visualizing the Distribution of 'Price' Column Using a Boxplot

# %%
plt.boxplot(inp1.Price)
plt.show()

# %% [markdown]
# ### Identifying Apps with Prices Above 200

# %%
inp1[inp1.Price>200]
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 4197          most expensive app (H)     FAMILY     4.3        6   1500.0
# 4362                      💎 I'm rich  LIFESTYLE     3.8      718  26000.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7300.0
# 5351                       I am rich  LIFESTYLE     3.8     3547   1800.0
# 5354                  I am Rich Plus     FAMILY     4.0      856   8700.0
# 5355                   I am rich VIP  LIFESTYLE     3.8      411   2600.0
# 5356               I Am Rich Premium    FINANCE     4.1     1867   4700.0
# 5357             I am extremely Rich  LIFESTYLE     2.9       41   2900.0
# 5358                      I am Rich!    FINANCE     3.8       93  22000.0
# 5359              I am rich(premium)    FINANCE     3.5      472      0.0
# 5362                   I Am Rich Pro     FAMILY     4.4      201   2700.0
# 5364  I am rich (Most expensive app)    FINANCE     4.1      129   2700.0
# 5366                       I Am Rich     FAMILY     3.6      217   4900.0
# 5369                       I am Rich    FINANCE     4.3      180   3800.0
# 5373              I AM RICH PRO PLUS    FINANCE     4.0       36  41000.0
#
#       Installs  Type   Price ContentRating         Genres CurrentVer  \
# 4197       100  Paid  399.99      Everyone  Entertainment          1
# 4362     10000  Paid  399.99      Everyone      Lifestyle      1.0.0
# 4367     10000  Paid  400.00      Everyone      Lifestyle      1.0.1
# 5351    100000  Paid  399.99      Everyone      Lifestyle          2
# 5354     10000  Paid  399.99      Everyone  Entertainment          3
# 5355     10000  Paid  299.99      Everyone      Lifestyle      1.1.1
# 5356     50000  Paid  399.99      Everyone        Finance        1.6
# 5357      1000  Paid  379.99      Everyone      Lifestyle          1
# 5358      1000  Paid  399.99      Everyone        Finance          1
# 5359      5000  Paid  399.99      Everyone        Finance        3.4
# 5362      5000  Paid  399.99      Everyone  Entertainment       1.54
# 5364      1000  Paid  399.99          Teen        Finance          2
# 5366     10000  Paid  389.99      Everyone  Entertainment        1.5
# 5369      5000  Paid  399.99      Everyone        Finance          1
# 5373      1000  Paid  399.99      Everyone        Finance      1.0.2
#
#         AndroidVer LastUpdated_Month_date LastUpdated_Year
# 4197    7.0 and up                July 16             2018
# 4362    4.4 and up               March 11             2018
# 4367    4.1 and up                  May 3             2018
# 5351  4.0.3 and up             January 12             2018
# 5354    4.4 and up                 May 19             2018
# 5355    4.3 and up                July 21             2018
# 5356    4.0 and up            November 12             2017
# 5357    4.0 and up                 July 1             2018
# 5358    4.1 and up            December 11             2017
# 5359    4.4 and up                  May 1             2017
# 5362    1.6 and up                 May 30             2017
# 5364  4.0.3 and up             December 6             2017
# 5366    4.2 and up                June 22             2018
# 5369    4.2 and up               March 22             2018
# 5373    4.1 and up                June 25             2018

# %% [markdown]
# ### Filtering Out Apps Priced Above 200

# %%
inp1=inp1[~(inp1.Price>200)]

# %% [markdown]
# ### Identifying Apps with Price Greater Than 200

# %%
inp1[inp1.Price>200]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, CurrentVer, AndroidVer, LastUpdated_Month_date, LastUpdated_Year]
# Index: []

# %% [markdown]
# ### Summary Statistics of 'Price' Data

# %%
inp1.Price.describe()
# Out:
# count    9347.000000
# mean        0.334887
# std         2.169735
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        79.990000
# Name: Price, dtype: float64

# %% [markdown]
# ### Plotting the Distribution of Non-Zero 'Price' Values

# %%
plt.boxplot(inp1[inp1.Price>0].Price)
plt.show()

# %% [markdown]
# ### Visualizing the Distribution of Positive 'Price' Values

# %%
inp1[inp1.Price>0].Price.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Filtering Apps with Price Greater Than 30

# %%
inp1[inp1.Price>30]
# Out:
#                             App   Category  Rating  Reviews     Size  \
# 2253  Vargo Anesthesia Mega App    MEDICAL     4.6       92  32000.0
# 2301    A Manual of Acupuncture    MEDICAL     3.5      214  68000.0
# 2365  Vargo Anesthesia Mega App    MEDICAL     4.6       92  32000.0
# 2402    A Manual of Acupuncture    MEDICAL     3.5      214  68000.0
# 2414               LTC AS Legal    MEDICAL     4.0        6   1300.0
# 5360           I am Rich Person  LIFESTYLE     4.2      134   1800.0
#
#       Installs  Type  Price ContentRating     Genres CurrentVer    AndroidVer  \
# 2253      1000  Paid  79.99      Everyone    Medical         19  4.0.3 and up
# 2301      1000  Paid  33.99      Everyone    Medical     2.1.35    4.0 and up
# 2365      1000  Paid  79.99      Everyone    Medical         19  4.0.3 and up
# 2402      1000  Paid  33.99      Everyone    Medical     2.1.35    4.0 and up
# 2414       100  Paid  39.99      Everyone    Medical      3.0.1    4.1 and up
# 5360      1000  Paid  37.99      Everyone  Lifestyle          1  4.0.3 and up
#
#      LastUpdated_Month_date LastUpdated_Year
# 2253                June 18             2018
# 2301              October 2             2017
# 2365                June 18             2018
# 2402              October 2             2017
# 2414                April 4             2018
# 5360                July 18             2017

# %% [markdown]
# ### Removing Rows with Price Greater Than 30

# %%
inp1=inp1[~(inp1.Price>30)]

# %% [markdown]
# ### Filtering Apps with Price Greater Than 30

# %%
inp1[inp1.Price>30]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, CurrentVer, AndroidVer, LastUpdated_Month_date, LastUpdated_Year]
# Index: []

# %% [markdown]
# ### Shape of Dataset for Apps Priced Above 30

# %%
inp1[inp1.Price>30].shape
# Out:
# (0, 14)

# %% [markdown]
# ### Visualizing 'Price' Distribution After Removing Zero-Price Entries

# %%
inp1[inp1.Price>0].Price.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## <center>Visualization using Histogram
# #####    Analyses numeric variable to visualise the frequency of records
# #####    Divides the range of numerical values to specific buckets or bins
# #####    Shows the no of records in each bin
# #####    Help in identifying buckets which have high frequency
# #####    X-axis-->Bin
# #####    Y-axis-->freqency

# %% [markdown]
# ### Viewing the Documentation for plt.hist

# %%
# ?plt.hist

# %% [markdown]
# ### Reviews = How are the reviews distributed (we used Histogram)

# %% [markdown]
# ### Visualizing the Distribution of 'Reviews' with a Histogram

# %%
plt.hist(inp1.Reviews)
plt.show()

# %% [markdown]
# ### Visualizing the Spread of 'Reviews' Using a Boxplot

# %%
plt.boxplot(inp1.Reviews)
plt.show()

# %% [markdown]
# ### Identifying Apps with Over 10 Million Reviews

# %%
inp1[inp1.Reviews>=10000000]
# Out:
#                                                     App       Category  \
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 336                                  WhatsApp Messenger  COMMUNICATION
# 342                                     Viber Messenger  COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure  COMMUNICATION
# 381                                  WhatsApp Messenger  COMMUNICATION
# ...                                                 ...            ...
# 6449                        BBM - Free Calls & Messages  COMMUNICATION
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 7937                                     Shadow Fight 2           GAME
# 8894  Cache Cleaner-DU Speed Booster (booster & clea...          TOOLS
# 8896  DU Battery Saver - Battery Charger & Battery Life          TOOLS
#
#       Rating   Reviews     Size    Installs  Type  Price ContentRating  \
# 335      4.0  56642847      0.0  1000000000  Free    0.0      Everyone
# 336      4.4  69119316      0.0  1000000000  Free    0.0      Everyone
# 342      4.3  11334799      0.0   500000000  Free    0.0      Everyone
# 378      4.5  17712922  40000.0   500000000  Free    0.0          Teen
# 381      4.4  69119316      0.0  1000000000  Free    0.0      Everyone
# ...      ...       ...      ...         ...   ...    ...           ...
# 6449     4.3  12843436      0.0   100000000  Free    0.0      Everyone
# 7536     4.7  24900999      0.0   500000000  Free    0.0      Everyone
# 7937     4.6  10981850  88000.0   100000000  Free    0.0  Everyone 10+
# 8894     4.5  12759815  15000.0   100000000  Free    0.0      Everyone
# 8896     4.5  13479633  14000.0   100000000  Free    0.0      Everyone
#
#              Genres          CurrentVer          AndroidVer  \
# 335   Communication  Varies with device  Varies with device
# 336   Communication  Varies with device  Varies with device
# 342   Communication  Varies with device  Varies with device
# 378   Communication         12.8.5.1121          4.0 and up
# 381   Communication  Varies with device  Varies with device
# ...             ...                 ...                 ...
# 6449  Communication  Varies with device        4.0.3 and up
# 7536          Tools               4.6.6  Varies with device
# 7937         Action              1.9.38          3.0 and up
# 8894          Tools               3.1.2          4.0 and up
# 8896          Tools             4.8.7.8          4.0 and up
#
#      LastUpdated_Month_date LastUpdated_Year
# 335                August 1             2018
# 336                August 3             2018
# 342                 July 18             2018
# 378                August 2             2018
# 381                August 3             2018
# ...                     ...              ...
# 6449               August 2             2018
# 7536               August 4             2018
# 7937                 July 2             2018
# 8894                July 25             2018
# 8896                 June 5             2018
#
# [92 rows x 14 columns]

# %% [markdown]
# ### Cleaning Data by Removing Apps with More Than 10 Million Reviews

# %%
inp1=inp1[~(inp1.Reviews>10000000)]

# %% [markdown]
# ### Identifying Apps with Over 10 Million Reviews after cleaning process

# %%
inp1[inp1.Reviews>=10000000]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, CurrentVer, AndroidVer, LastUpdated_Month_date, LastUpdated_Year]
# Index: []

# %% [markdown]
# ### Viewing the Number of Rows and Columns in inp1

# %%
inp1.shape
# Out:
# (9249, 14)

# %% [markdown]
# ### Displaying the Frequency of Review Counts in a Histogram after cleaning

# %%
plt.hist(inp1.Reviews)
plt.show()

# %% [markdown]
# ### Visualizing the Spread of 'Installs' with a Boxplot

# %%
plt.boxplot(inp1.Installs)
plt.show()

# %% [markdown]
# ### Descriptive Statistics of 'Installs' Values

# %%
inp1.Installs.describe()
# Out:
# count    9.249000e+03
# mean     1.303116e+07
# std      6.864485e+07
# min      1.000000e+00
# 25%      1.000000e+04
# 50%      5.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %% [markdown]
# ## <center>Visualization using Seaborn feature
# ##### python library to create statistical graphs easily.
# #####    Built on top of matplotlib and closely intergrated with pandas
# #####    Functionalities of seaborn:
# #####        Dataset oriented API
# #####        Analysing univariate and bivariate distribution
# #####        Automatic estimation and plotting of linear regression models
# #####        Convenient views for complex datasets
# #####        Concise control over style
# #####        Colour palettes

# %% [markdown]
# ### Count of Unique Values in the 'Size' Column

# %%
inp1.Size.value_counts()
# Out:
# 0.0        1845
# 14000.0     165
# 12000.0     161
# 11000.0     160
# 13000.0     157
#            ...
# 89000.0       9
# 65000.0       9
# 86000.0       8
# 90000.0       5
# 1000.0        4
# Name: Size, Length: 182, dtype: int64

# %% [markdown]
# ### Ignoring Warnings for Cleaner Output

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Visualizing 'Rating' Distribution with a Histogram

# %%
inp1.Rating.plot.hist()
plt.show()

# %% [markdown]
# ### Importing Seaborn libraries

# %%
import seaborn as sns

# %% [markdown]
# ## <center> Visulization using DIST Plot

# %% [markdown]
# ### Understanding the Rating Distribution of Apps Using Seaborn's Distplot

# %%
sns.distplot(inp1.Rating)
plt.show()

# %% [markdown]
# ### Plotting the Distribution of App Ratings with 20 Bins (Seaborn)

# %%
sns.distplot(inp1.Rating,bins=20)
plt.show()

# %% [markdown]
# ### Visualizing 'Rating' Distribution with Seaborn Distplot (20 Bins, Green Color)

# %%
sns.distplot(inp1.Rating,bins=20,color="g")
plt.show()

# %% [markdown]
# ### Use different Styles

# %% [markdown]
# ### Changing Plot Background and Gridlines with Seaborn's set_style()

# %%
# ?sns.set_style

# %% [markdown]
# ### Customizing Plot Aesthetics with Seaborn's set_style()

# %%
sns.set_style()

# %% [markdown]
# ### Viewing Predefined Plot Styles in Matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### Applying Dark Background Style to Matplotlib Plots

# %%
plt.style.use("dark_background")

# %% [markdown]
# ### Visualizing the Distribution of Ratings with Seaborn's Distplot (20 Bins)

# %%
sns.distplot(inp1.Rating,bins=20)
plt.show()

# %% [markdown]
# ### Using 'ggplot' Style for Seaborn Distribution Plot of Ratings

# %%
plt.style.use("ggplot")
sns.distplot(inp1.Rating,bins=20)
plt.show()

# %% [markdown]
# ### Restoring Default Plot Style in Matplotlib and Enabling Inline Plots

# %%
plt.style.use("default")
# %matplotlib inline

# %% [markdown]
# ### Visualizing the Correlation Between App Size and Rating Using Seaborn

# %%
sns.jointplot(inp1.Size,inp1.Rating)
plt.show()

# %% [markdown]
# ## <center> Visulization using JOINT Plot

# %% [markdown]
# ### Exploring the Relationship Between Price and Rating Using Seaborn's Jointplot

# %%
sns.jointplot(inp1.Price,inp1.Rating)
plt.show()

# %% [markdown]
# ### Exploring the Linear Relationship Between Price and Rating with Seaborn's Jointplot (Regression)

# %%
sns.jointplot(inp1.Price,inp1.Rating,kind="reg")
plt.show()

# %% [markdown]
# ## <center> Visualization Using PAIR Plot

# %% [markdown]
# ### Visualizing Relationships Between Reviews, Size, Price, and Rating with Seaborn's Pairplot

# %%
sns.pairplot(inp1[['Reviews','Size','Price','Rating']])
plt.show()

# %% [markdown]
# ### Relationships Between Rating, Reviews, and Price (Pair Plot)

# %%
# Assuming inp1 is your DataFrame
# Create a pair plot for 'Rating', 'Reviews', and 'Price'
sns.pairplot(inp1[['Rating', 'Reviews', 'Price']], diag_kind='kde')

# Add a title
plt.suptitle('Pair Plot of Rating, Reviews, and Price', y=1.02)

# Show the plot
plt.show()

# %% [markdown]
# ### Visualizing Rating Distribution Across Content Ratings with Seaborn Boxplot

# %%
plt.figure(figsize=[9,7])
sns.boxplot(inp1['ContentRating'],inp1.Rating)
plt.show()

# %% [markdown]
# ## <center> Visualization using HEATMAP

# %% [markdown]
# ### <center>Rating vs Size vs content Rating

# %% [markdown]
# ### Using pd.qcut for Discretizing Continuous Data into Quantiles

# %%
# ?pd.qcut

# %% [markdown]
# ### Discretizing App Size into Quantile-Based Categories (VL, L, M, H, VH)

# %%
inp1['Size_Bucket']=pd.qcut(inp1.Size,[0,0.2,0.4,0.6,0.8,1],["VL","L","M","H","VH"])

# %% [markdown]
# ### Inspecting the First Few Entries in the inp1 DataFrame

# %%
inp1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price ContentRating  \
# 0      159  19000.0     10000  Free    0.0      Everyone
# 1      967  14000.0    500000  Free    0.0      Everyone
# 2    87510   8700.0   5000000  Free    0.0      Everyone
# 3   215644  25000.0  50000000  Free    0.0          Teen
# 4      967   2800.0    100000  Free    0.0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
#
#   LastUpdated_Month_date LastUpdated_Year Size_Bucket
# 0              January 7             2018           H
# 1             January 15             2018           M
# 2               August 1             2018           M
# 3                 June 8             2018           H
# 4                June 20             2018           L

# %% [markdown]
# ### Summary of Ratings by Content Rating and Size Bucket

# %%
pd.pivot_table(data=inp1,index="ContentRating",columns="Size_Bucket",values="Rating")
# Out:
# Size_Bucket          VL         L         M         H        VH
# ContentRating
# Everyone       4.233801  4.137606  4.176055  4.172851  4.219262
# Everyone 10+   4.226316  4.218182  4.257500  4.237755  4.251773
# Mature 17+     4.212088  4.096774  4.087129  4.018812  4.194175
# Teen           4.260476  4.173387  4.221557  4.187554  4.274850

# %% [markdown]
# ### Analyzing Median Ratings Across Content Ratings and Size Categories

# %%
pd.pivot_table(data=inp1,index="ContentRating",columns="Size_Bucket",values="Rating",aggfunc=np.median)
# Out:
# Size_Bucket     VL     L     M    H   VH
# ContentRating
# Everyone       4.3  4.20  4.30  4.3  4.3
# Everyone 10+   4.3  4.25  4.35  4.3  4.3
# Mature 17+     4.2  4.25  4.20  4.1  4.2
# Teen           4.3  4.30  4.30  4.2  4.3

# %% [markdown]
# ### Analyzing App Ratings (Median) Across Different Content Ratings and Size Buckets

# %%
pd.pivot_table(data=inp1,index="ContentRating",columns="Size_Bucket",values="Rating",aggfunc=np.median)
# Out:
# Size_Bucket     VL     L     M    H   VH
# ContentRating
# Everyone       4.3  4.20  4.30  4.3  4.3
# Everyone 10+   4.3  4.25  4.35  4.3  4.3
# Mature 17+     4.2  4.25  4.20  4.1  4.2
# Teen           4.3  4.30  4.30  4.2  4.3

# %% [markdown]
# ### Exploring the 20th Percentile of App Ratings Across Content Ratings and Size Buckets

# %%
res=pd.pivot_table(data=inp1,index="ContentRating",columns="Size_Bucket",values="Rating",aggfunc=lambda x:np.quantile(x,0.2))

# %% [markdown]
# ### Heatmap of Data Relationships

# %%
sns.heatmap(res)
# Out:
# <AxesSubplot:xlabel='Size_Bucket', ylabel='ContentRating'>

# %% [markdown]
# ### Data Heatmap with Green Color Scale and Annotations

# %%
sns.heatmap(res,cmap="Greens",annot=True)
# Out:
# <AxesSubplot:xlabel='Size_Bucket', ylabel='ContentRating'>

# %% [markdown]
# ### Inspecting the First Few Entries in the inp1 DataFrame

# %%
inp1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price ContentRating  \
# 0      159  19000.0     10000  Free    0.0      Everyone
# 1      967  14000.0    500000  Free    0.0      Everyone
# 2    87510   8700.0   5000000  Free    0.0      Everyone
# 3   215644  25000.0  50000000  Free    0.0          Teen
# 4      967   2800.0    100000  Free    0.0      Everyone
#
#                       Genres          CurrentVer    AndroidVer  \
# 0               Art & Design               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2               Art & Design               1.2.4  4.0.3 and up
# 3               Art & Design  Varies with device    4.2 and up
# 4    Art & Design;Creativity                 1.1    4.4 and up
#
#   LastUpdated_Month_date LastUpdated_Year Size_Bucket
# 0              January 7             2018           H
# 1             January 15             2018           M
# 2               August 1             2018           M
# 3                 June 8             2018           H
# 4                June 20             2018           L

# %% [markdown]
# ## <center>Visualization using PIE-CHART

# %% [markdown]
# ### Distribution of App Types (Paid vs Free)

# %%
type_counts = inp1['Type'].value_counts()
# Create a pie chart
plt.figure(figsize=(6,6))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('App Type Distribution (Paid/Free)')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.show()

# %% [markdown]
# ## <center>Visualization using COUNT Plot

# %% [markdown]
# ### Frequency Distribution of App Types

# %%
sns.countplot(data=inp1, x='Type')
plt.title('Distribution of App Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## <center> Visulization using KDE plot

# %% [markdown]
# ### Kernel Density Estimate of Paid vs Free Apps (Mapped to Numeric)

# %%
inp1['Type_num'] = inp1['Type'].map({'Paid': 1, 'Free': 0})
# Now, plot the KDE (it will show a distribution of 0s and 1s)
sns.kdeplot(inp1['Type_num'])
plt.title('Kernel Density Estimate for App Type (Mapped to Numeric)')
plt.xlabel('Type (0 = Free, 1 = Paid)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## <center> Visulization using SCATTER Plot

# %% [markdown]
# ### Scatter Plot of App Size vs Price (Grouped by Type

# %%
sns.scatterplot(x="Size", y="Price", hue="Type", data=inp1)

# Add titles and labels for better understanding
plt.title('Scatter Plot of Size vs Price with Type Hue')  # Title of the plot
plt.xlabel('Size')  # Label for x-axis
plt.ylabel('Price')  # Label for y-axis

# Show the plot
plt.show()

# %% [markdown]
# ## <center> Visualization using VIOLIN Plot

# %% [markdown]
# ### Violin Plot Showing the Distribution of App Ratings

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x=inp1['Rating'], color='lightcoral')

# Add title and labels
plt.title('Violin Plot of Ratings', fontsize=16)
plt.xlabel('Rating', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ### Importing Scipy.stats for Advanced Statistical Tools

# %%
import scipy.stats as stats

# %% [markdown]
# ## <center> Visulization using Q-Q PLOT

# %% [markdown]
# ### Quantile-Quantile Plot of App Ratings vs. Normal Distribution

# %%
plt.figure(figsize=(10, 6))

# Create a Q-Q plot to compare the distribution of 'Rating' to a normal distribution
stats.probplot(inp1['Rating'], dist="norm", plot=plt)

# Add title
plt.title('Q-Q Plot of Ratings')

# Show the plot
plt.show()

# %% [markdown]
# ## <center> Visualization using a PAIR Plot

# %% [markdown]
# ### Relationships Between Rating, Reviews, and Price (Pair Plot)

# %%
# Assuming inp1 is your DataFrame
# Create a pair plot for 'Rating', 'Reviews', and 'Price'
sns.pairplot(inp1[['Rating', 'Reviews', 'Price']], diag_kind='kde')

# Add a title
plt.suptitle('Pair Plot of Rating, Reviews, and Price', y=1.02)

# Show the plot
plt.show()

# %% [markdown]
# ### Visualizing App Price Distribution with a Box Plot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=inp1['Price'], color='lightgreen')
# Add corrected title and labels
plt.title('Box Plot of App Prices', fontsize=16)
plt.xlabel('Price (in USD)', fontsize=12)
# Show the plot
plt.show()
